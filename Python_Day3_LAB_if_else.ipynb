# %% [markdown]
# # Python Day 3 — LAB: `if / elif / else`Try it yourself first, then ask your neighbour, then ask me.

# %% [markdown]
# ## P1 — True or FalseBefore running, guess the answer. Then print each condition.

# %%
sales = 957.58# print whether sales is greater than 500# print whether sales equals 957.58# print whether sales is less than 100# your code here

# %% [markdown]
# ## P2 — Your first ifPrint `"Big order"` only if `sales` is above 500.

# %%
sales = 957.58# your code here

# %% [markdown]
# ## P3 — if / elsePrint `"Profitable"` if profit is above zero, otherwise `"Loss"`.Then change profit to a negative number and run it again.

# %%
profit = 219.58# your code here

# %% [markdown]
# ## P4 — Three bandsUsing `if / elif / else`, print:- `High` if sales are 1000 or more- `Medium` if 100 or more- `Low` otherwiseTest with 1500, then 500, then 50.

# %%
sales = 500# your code here

# %% [markdown]
# ## P5 — Two conditions with `and`Print `"Good sale"` only if sales are above 500 **and** profit is above zero.

# %%
sales = 731.94profit = 219.58# your code here

# %% [markdown]
# ## P6 — `or`Print `"Coastal"` if the region is West **or** East, otherwise `"Inland"`.

# %%
region = "East"# your code here

# %% [markdown]
# ## P7 — Discount checkIf discount is greater than 0, print how much as a percentage(e.g. `Discount: 20%`). Otherwise print `No discount`.*Hint: `discount * 100`*

# %%
discount = 0.2# your code here

# %% [markdown]
# ## CHALLENGE — Order reportUsing the values below, print a report like this:```Order:   US-2015-108966Band:    MediumStatus:  LossDiscount: 45%```Work out the band with `if/elif/else`, the status from profit,and the discount line from the discount value.

# %%
order_id = "US-2015-108966"sales    = 957.58profit   = -383.03discount = 0.45# your code here
