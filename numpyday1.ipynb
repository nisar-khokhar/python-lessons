# %%
import numpy as np
import pandas as pd
price = np.array([100,200,300])
print(price*2)
# Out:
# [200 400 600]

# %%
price  = [100,200,300]
for index,i in enumerate(price):
    i = i * 2
    price[index]=i
print(price)
# Out:
# [200, 400, 600]

# %%
df = pd.DataFrame({"Sales":[250,800,1200,450]})

# %%
df
# Out:
#    Sales
# 0    250
# 1    800
# 2   1200
# 3    450

# %%
print(df['Sales'].values)
# Out:
# [ 250  800 1200  450]

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
s = np.linspace(0,10,5)
s
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
s = np.arange(0,10,2)
s
# Out:
# array([0, 2, 4, 6, 8])

# %%
e = np.zeros(5 ,dtype=int)
print(e)
print(type(e[0]))
# Out:
# [0 0 0 0 0]
# <class 'numpy.int64'>

# %%
f = np.ones(4, dtype=int)
f
# Out:
# array([1, 1, 1, 1])

# %%
g = np.array([[1,2,3],
              [4,5,6]])
g[0,0:2]
# Out:
# array([1, 2])

# %%
g.T
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
g = g.reshape(3,2)

# %%
g.ndim
# Out:
# 2

# %%
g.shape
# Out:
# (3, 2)

# %%
g[1][1]
# Out:
# np.int64(4)

# %%
g.size
# Out:
# 6

# %%
g.dtype
# Out:
# dtype('int64')

# %%
w = np.array([[1,2,3],[4,5,6]])
w[0:2]
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a = np.array([10,4,7,12,15])
a
# Out:
# array([10,  4,  7, 12, 15])

# %%
a[(a>5) & (a<12)]
# Out:
# array([10,  7])

# %%
q = np.array([5,12,7,28,3])
t = np.where(q>10, "High", "Low")

print(q,t)
# Out:
# [ 5 12  7 28  3] ['Low' 'High' 'Low' 'High' 'Low']

# %%
a = np.array([10,20,30,40])
print(a[a>10].sum(), a.sum(), a.mean(), a.min(), a.max())
# Out:
# 90 100 25.0 10 40

# %%
a = np.array([[1,2,3],[4,5,6]])
print(a.sum() , a.sum(axis=0), a.sum(axis=1))
# Out:
# 21 [5 7 9] [ 6 15]

# %%
df['Tier'] = np.where(df["Sales"]>1000 , "high", "low")
df
# Out:
#    Sales  Tier
# 0    250   low
# 1    800   low
# 2   1200  high
# 3    450   low
