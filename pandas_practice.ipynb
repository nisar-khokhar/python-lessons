# %%
order = [{"Customer_name": "Ali", "Sales": 201, "Region": "Central"},
         {"Customer_name": "Hassan", "Sales": 101, "Region": "West"},
         {"Customer_name": "Hussain", "Sales": 301, "Region": "North"}]

# %%
import pandas as pd
df = pd.DataFrame(order)

# %%
print(df)
# Out:
#   Customer_name  Sales   Region
# 0           Ali    201  Central
# 1        Hassan    101     West
# 2       Hussain    301    North

# %%
df1 = pd.read_csv("superstore.csv");
print(df1.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky  South
# 1      Claire Gute   Consumer        Henderson    Kentucky  South
# 2  Darrin Van Huff  Corporate      Los Angeles  California   West
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df1[["Sales","Customer Name", "City"]].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales          180 non-null    float64
#  1   Customer Name  180 non-null    str
#  2   City           180 non-null    str
# dtypes: float64(1), str(2)
# memory usage: 4.3 KB

# %%
sale = [234.456 , 764]
print(sale)
# Out:
# [234.456, 764]

# %%
for i in sale:
    tax_ret = i * 1.25
    print(f"this is the old {i} and this is new {tax_ret}")
# Out:
# this is the old 234.456 and this is new 293.07
# this is the old 764 and this is new 955.0

# %%
taxed_sale = (df1["Sales"] * 1.25)
print(df1["Sales"])
# Out:
# 0      261.9600
# 1      731.9400
# 2       14.6200
# 3      957.5775
# 4       22.3680
#          ...
# 175     20.1600
# 176     97.2640
# 177    396.8020
# 178     15.8800
# 179      3.2800
# Name: Sales, Length: 180, dtype: float64

# %%
print(taxed_sale)
# Out:
# 0       327.450000
# 1       914.925000
# 2        18.275000
# 3      1196.971875
# 4        27.960000
#           ...
# 175      25.200000
# 176     121.580000
# 177     496.002500
# 178      19.850000
# 179       4.100000
# Name: Sales, Length: 180, dtype: float64

# %%
print(df1["Sales"].sum())
# Out:
# 44680.5977

# %%
print(df1["Sales"].min())
# Out:
# 1.248

# %%
df1["Sales"] > 1000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# Name: Sales, Length: 180, dtype: bool

# %%
df1[df1["Sales"] > 1000]
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 10       11  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 24       25  CA-2015-106320  2015-09-25  2015-09-30  Standard Class
# 27       28  US-2015-150630  2015-09-17  2015-09-21  Standard Class
# 35       36  CA-2016-117590  2016-12-08  2016-12-10     First Class
# 54       55  CA-2016-105816  2016-12-11  2016-12-17  Standard Class
# 67       68  CA-2014-106376  2014-12-05  2014-12-10  Standard Class
# 149     150  CA-2016-114489  2016-12-05  2016-12-09  Standard Class
# 165     166  CA-2014-139892  2014-09-08  2014-09-12  Standard Class
# 167     168  CA-2014-139892  2014-09-08  2014-09-12  Standard Class
#
#     Customer ID    Customer Name    Segment           City       State  \
# 10     BH-11710  Brosina Hoffman   Consumer    Los Angeles  California
# 24     EB-13870      Emily Burns   Consumer           Orem        Utah
# 27     TB-21520  Tracy Blumstein   Consumer        Jackson    Michigan
# ...

# %%
df1[df1["Region"] == "West"]
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2         3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 5         6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 6         7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 7         8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 8         9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# ..      ...             ...         ...         ...             ...
# 162     163  CA-2016-154508  2016-11-16  2016-11-20  Standard Class
# 163     164  CA-2016-113817  2016-11-07  2016-11-11  Standard Class
# 171     172  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
# 172     173  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
# 173     174  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
#
#     Customer ID    Customer Name    Segment         City       State Region  \
# ...

# %%
df[(df["Region"] == "West") & (df["Sales"] > 500)]
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7         8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 10       11  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 11       12  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 24       25  CA-2015-106320  2015-09-25  2015-09-30  Standard Class
# 67       68  CA-2014-106376  2014-12-05  2014-12-10  Standard Class
# 117     118  CA-2015-110457  2015-03-02  2015-03-06  Standard Class
# 145     146  CA-2015-110744  2015-09-07  2015-09-12  Standard Class
#
#     Customer ID    Customer Name    Segment         City       State Region  \
# 7           NaN  Brosina Hoffman   Consumer  Los Angeles  California   West
# 10     BH-11710  Brosina Hoffman   Consumer  Los Angeles  California   West
# 11     BH-11710  Brosina Hoffman   Consumer  Los Angeles  California   West
# 24     EB-13870      Emily Burns   Consumer         Orem        Utah   West
# ...

# %%
df["Region"].value_counts()
# Out:
# Region
# Central    65
# West       62
# East       37
# South      16
# Name: count, dtype: int64

# %%
#fetch specific product id
df[df["Product ID"] == "TEC-PH-10002275"]
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 7       8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class         NaN
#
#      Customer Name   Segment         City       State Region       Product ID  \
# 7  Brosina Hoffman  Consumer  Los Angeles  California   West  TEC-PH-10002275
#
#      Category Sub-Category                    Product Name    Sales  Quantity  \
# 7  Technology       Phones  Mitel 5320 IP Phone VoIP phone  907.152       6.0
#
#    Discount   Profit
# 7       0.2  90.7152
