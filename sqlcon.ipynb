# %%
import sys
!"{sys.executable}" -m pip install sqlalchemy pyodbc
# Out:
# Requirement already satisfied: sqlalchemy in c:\Users\Malik Nisar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.0.53)
# Requirement already satisfied: pyodbc in c:\Users\Malik Nisar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (5.3.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\Malik Nisar\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sqlalchemy) (3.5.6)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Malik Nisar\AppData\Roaming\Python\Python314\site-packages (from sqlalchemy) (4.16.0)
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests 
import pandas as pd

API_KEY = "b238da37213d7fa7c9edc37eec6312a5"
City = "Lahore"
url = 'https://api.openweathermap.org/data/2.5/weather'
params = {"q": City, "appid": API_KEY, "units": "metric"}
res = requests.get(url, params=params)

# %%
resp = res.json()
df = pd.DataFrame([resp])
df
# Out:
#                               coord  \
# 0  {'lon': 74.3436, 'lat': 31.5497}
#
#                                              weather      base  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations
#
#                                                 main  visibility  \
# 0  {'temp': 30.99, 'feels_like': 37.57, 'temp_min...       10000
#
#                           wind      clouds          dt  \
# 0  {'speed': 1.03, 'deg': 330}  {'all': 2}  1789480553
#
#                                                  sys  timezone       id  \
# 0  {'type': 1, 'id': 7585, 'country': 'PK', 'sunr...     18000  1172451
#
#      name  cod
# 0  Lahore  200

# %%
print("Response Status Code:", res.status_code)
# Out:
# Response Status Code: 200
