# %% [markdown]
# # Python Day 2 — LABWork through these yourself. Try first, then ask your neighbour, then ask me.Write your answer in the empty cell under each question and press `Shift + Enter`.

# %% [markdown]
# ## P1 — Clean the cityMake the value below print exactly: `Los Angeles`*Hint: `.strip()` and `.title()`*

# %%
raw = "   LOS angeles   "# your code here

# %% [markdown]
# ## P2 — Fix the currencyTurn the value below into the **number** `160.0`, then add 100 to prove it is really a number.*Hint: `.strip()`, `.replace()`, `float()`*

# %%
revenue = "  160 € "# your code here

# %% [markdown]
# ## P3 — Split a codeFrom the order id below, print the country code and the year on separate lines.*Hint: `.split("-")`*

# %%
order_id = "US-2015-108966"# your code here

# %% [markdown]
# ## P4 — List summaryUsing the sales list, print: the count, the total, the average (2 decimals),the highest value, and the **top 2** values.

# %%
sales = [261.96, 731.94, 14.62, 957.58, 22.37]# your code here

# %% [markdown]
# ## P5 — Unique regionsPrint how many **unique** regions there are, and how many times `"West"` appears.

# %%
regions = ["West", "East", "West", "Central", "South", "West"]# your code here

# %% [markdown]
# ## P6 — Your first ifPrint `Profitable` if profit is above zero, otherwise print `Loss`.Then change the number and run it again.

# %%
profit = 250.75# your code here

# %% [markdown]
# ## CHALLENGE — Band a saleUsing `if / elif / else`, print:- `High` if the sale is 1000 or more- `Medium` if it is 100 or more- `Low` otherwiseTest it with 1500, then 500, then 50.

# %%
sale = 500# your code here
