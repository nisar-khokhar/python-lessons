# %% [markdown]
# # Functions — LABTry it yourself first, then ask your neighbour, then ask me.Write your answer in the empty cell under each question.

# %% [markdown]
# ## P1 — No inputWrite a function `hello()` that returns the text `"Hello Python"`. Then print it.

# %%
# your code here

# %% [markdown]
# ## P2 — One inputWrite `triple(number)` that returns the number times 3.Test it with 5 and 20.

# %%
# your code here

# %% [markdown]
# ## P3 — Text inputWrite `full_name(first, last)` that returns both joined by a space.Test it with `"Muhammad"` and `"Atif"`.

# %%
# your code here

# %% [markdown]
# ## P4 — Two numbersWrite `area(length, width)` that returns length x width. Test with 5 and 3.

# %%
# your code here

# %% [markdown]
# ## P5 — return, not printWrite `add_tax(amount)` that **returns** the amount x 1.15.Store the answer in a variable, then print it rounded to 2 decimals.

# %%
# your code here

# %% [markdown]
# ## P6 — Returning True/FalseWrite `is_big(sale)` that returns `True` if the sale is over 500, otherwise `False`.Test with 731.94 and 14.62.*Hint: you do not need an if — `sale > 500` is already True or False.*

# %%
# your code here

# %% [markdown]
# ## P7 — Fix the broken functionThis fails. Work out why, then fix it so the last line prints 120.

# %%
def total(values):    print(sum(values))t = total([10, 20, 30])print(t * 2)          # should print 120# fix it below

# %% [markdown]
# ## P8 — A function with a loop insideWrite `count_negative(values)` that returns how many values are below zero.

# %%
profits = [41.91, 219.58, -7.75, -383.03, 85.31, -12.40]# your code here

# %% [markdown]
# ## P9 — A function that bands a valueWrite `band(sale)` that returns `"High"` (1000 or more), `"Medium"` (100 or more)or `"Low"`. Test it with 1500, 500 and 50.

# %%
# your code here

# %% [markdown]
# ## CHALLENGE — Put it all togetherUse your `band()` function inside a loop to build a list called `bands`from the sales list. Print both lists, then print how many are "High".

# %%
sales = [1706.18, 731.94, 14.62, 957.58, 22.37, 1200.00]# your code here
