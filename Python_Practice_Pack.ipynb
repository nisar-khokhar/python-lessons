# %% [markdown]
# # Python Practice Pack### Everything covered so far**Sections**- A. Variables, types, f-strings- B. Strings- C. Lists- D. if / elif / else- E. Loops- F. Functions- G. pandas- H. Mixed challengesWork at your own pace. Try first, then ask your neighbour, then ask me.Answers are in the solutions file — use it only after you have attempted the question.

# %% [markdown]
# ---# SECTION A — Variables, types, f-strings

# %% [markdown]
# ### A1Create variables for a product name, its price (decimal) and quantity (whole number).Print all three on separate lines.

# %%
# your code here

# %% [markdown]
# ### A2Calculate the total cost (price x quantity) and print it as `Total: $1,234.56`— 2 decimals and a thousands separator.

# %%
# your code here

# %% [markdown]
# ### A3Print the `type()` of each of your three variables.

# %%
# your code here

# %% [markdown]
# ### A4`revenue = 44680.60` and `orders = 180`. Print the average order valueto 2 decimals, and the profit margin `-598.30 / 44680.60` as a percentagewith 2 decimals.

# %%
revenue = 44680.60orders = 180profit = -598.30# your code here

# %% [markdown]
# ### A5What is wrong here? Fix it so it prints 15.

# %%
a = "10"b = 5print(a + b)# fix it below

# %% [markdown]
# ---# SECTION B — Strings

# %% [markdown]
# ### B1Clean this so it prints exactly `Los Angeles`.

# %%
raw = "   LOS angeles   "# your code here

# %% [markdown]
# ### B2Turn this text into the NUMBER 1394.0, then add 100 to prove it is numeric.

# %%
revenue = "  1394 € "# your code here

# %% [markdown]
# ### B3From the order id, print the country code and the year on separate lines.

# %%
order_id = "US-2015-108966"# your code here

# %% [markdown]
# ### B4This value has spaces at the ends AND in the middle.Make it print `Central Region` — single spaces only.*Hint: `" ".join(text.split())`*

# %%
messy = "     Central          Region    "# your code here

# %% [markdown]
# ### B5Print how many characters are in the product name, and the name in UPPERCASE.

# %%
product = "Bush Somerset Collection Bookcase"# your code here

# %% [markdown]
# ---# SECTION C — Lists

# %% [markdown]
# ### C1Print the first item, the last item, and how many items there are.

# %%
sales = [261.96, 731.94, 14.62, 957.58, 22.37, 1706.18]# your code here

# %% [markdown]
# ### C2Print the first 3 items, the last 2 items, and items 2 to 4.

# %%
# your code here

# %% [markdown]
# ### C3Print the total, average (2 decimals), biggest and smallest.

# %%
# your code here

# %% [markdown]
# ### C4Print the TOP 3 sales, biggest first.

# %%
# your code here

# %% [markdown]
# ### C5Add 500.00 to the list, remove 14.62, then print the new total.

# %%
# your code here

# %% [markdown]
# ### C6How many UNIQUE regions are there, and how many times does "West" appear?

# %%
regions = ["West", "East", "West", "Central", "South", "West", "East"]# your code here

# %% [markdown]
# ---# SECTION D — if / elif / else

# %% [markdown]
# ### D1Print `Profitable` if profit is above zero, otherwise `Loss`.

# %%
profit = -383.03# your code here

# %% [markdown]
# ### D2Band the sale: `High` (1000+), `Medium` (100+), `Low`.Test with 1500, 500 and 50.

# %%
sale = 500# your code here

# %% [markdown]
# ### D3Print `Coastal` if the region is West or East, otherwise `Inland`.

# %%
region = "East"# your code here

# %% [markdown]
# ### D4Print `Good sale` only if sales are above 500 AND profit is above zero.

# %%
sales = 731.94profit = 219.58# your code here

# %% [markdown]
# ### D5If discount is above 0, print it as a percentage (e.g. `Discount: 20%`).Otherwise print `No discount`.

# %%
discount = 0.2# your code here

# %% [markdown]
# ---# SECTION E — Loops

# %% [markdown]
# ### E1Print every region on its own line.

# %%
regions = ["Central", "West", "East", "South"]# your code here

# %% [markdown]
# ### E2Use `range()` to print the numbers 1 to 10.

# %%
# your code here

# %% [markdown]
# ### E3Build a running total of the profits WITHOUT using `sum()`.

# %%
profits = [41.91, 219.58, 6.87, -383.03, 2.52, 14.17]# your code here

# %% [markdown]
# ### E4Count how many sales are over 500.

# %%
sales = [261.96, 731.94, 14.62, 957.58, 1706.18, 22.37]# your code here

# %% [markdown]
# ### E5Add up ONLY the positive profits.

# %%
# your code here

# %% [markdown]
# ### E6Build a NEW list called `with_tax` containing each sale x 1.15, rounded to 2 decimals.

# %%
# your code here

# %% [markdown]
# ### E7Use `zip()` to print each region next to its revenue, nicely aligned.

# %%
regions = ["Central", "West", "East", "South"]revenue = [24990.19, 11830.35, 4496.16, 3363.90]# your code here

# %% [markdown]
# ---# SECTION F — Functions

# %% [markdown]
# ### F1Write `triple(number)` that RETURNS the number x 3. Test with 5 and 20.

# %%
# your code here

# %% [markdown]
# ### F2Write `average(values)` that returns the average of a list, rounded to 2 decimals.

# %%
# your code here

# %% [markdown]
# ### F3Write `is_big(sale)` that returns True if the sale is over 500, otherwise False.*You do not need an if.*

# %%
# your code here

# %% [markdown]
# ### F4Fix this so the last line prints 120.

# %%
def total(values):    print(sum(values))t = total([10, 20, 30])print(t * 2)# fix it below

# %% [markdown]
# ### F5Write `count_negative(values)` that returns how many values are below zero.

# %%
profits = [41.91, 219.58, -7.75, -383.03, 85.31, -12.40]# your code here

# %% [markdown]
# ### F6Write `band(sale)` returning High / Medium / Low, then use it in a loopto build a list of bands.

# %%
sales = [1706.18, 731.94, 14.62, 957.58, 22.37]# your code here

# %% [markdown]
# ---# SECTION G — pandas`superstore.csv` must be in the same folder as this notebook.

# %%
import pandas as pddf = pd.read_csv("superstore.csv")df.head()

# %% [markdown]
# ### G1Print the shape and the column names.

# %%
# your code here

# %% [markdown]
# ### G2Print total sales, average sale, largest sale and total profit — formatted to 2 decimals.

# %%
# your code here

# %% [markdown]
# ### G3Show only the columns `Customer Name`, `Region` and `Sales` (first 5 rows).

# %%
# your code here

# %% [markdown]
# ### G4How many rows have Sales over 1000?

# %%
# your code here

# %% [markdown]
# ### G5How many rows are from the West region?

# %%
# your code here

# %% [markdown]
# ### G6Show rows that are in the West region AND have Sales over 500.

# %%
# your code here

# %% [markdown]
# ### G7Total sales by Region, biggest first.

# %%
# your code here

# %% [markdown]
# ### G8Total profit by Category. Which category loses money?

# %%
# your code here

# %% [markdown]
# ### G9The 5 biggest sales, showing only Product Name and Sales.

# %%
# your code here

# %% [markdown]
# ### G10Add a new column `Sales_with_tax` = Sales x 1.15 and show the first 5 rowsof `Sales` and `Sales_with_tax`.

# %%
# your code here

# %% [markdown]
# ---# SECTION H — Mixed challenges

# %% [markdown]
# ### H1 — Report from listsUsing the two lists, print a summary showing: row count, total, average,how many are over 500, and how many unique regions.

# %%
sales   = [261.96, 731.94, 14.62, 957.58, 1706.18, 22.37]regions = ["South", "South", "West", "South", "West", "East"]# your code here

# %% [markdown]
# ### H2 — Clean and totalThese revenue values are messy text. Clean each one, convert to a number,and print the total.

# %%
raw_revenue = ["  160 € ", "  1394 € ", "  75 € ", "  218 € "]# your code here

# %% [markdown]
# ### H3 — Function + loop + pandas1. Write a function `band(sale)` returning High / Medium / Low2. Use it to add a `Band` column to the DataFrame   *Hint: build a list in a loop, then `df["Band"] = your_list`*3. Count how many rows are in each band

# %%
# your code here
