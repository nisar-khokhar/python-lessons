# %% [markdown]
# # pandas Day 1 — LAB
#
# `superstore.csv` must be in the same folder as this notebook.
# Try it yourself first, then ask your neighbour, then ask me.

# %% [markdown]
# ## Setup — run this first

# %%
import pandas as pd

df = pd.read_csv("superstore.csv")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State Region  \
# 0      Claire Gute   Consumer        Henderson    Kentucky  South
# 1      Claire Gute   Consumer        Henderson    Kentucky  South
# 2  Darrin Van Huff  Corporate      Los Angeles  California   West
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  South
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  South
#
#         Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## P1 — Look at the data
# Print the shape, the column names, and the first 10 rows.

# %%
# your code here
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812  2014-06-09  2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment             City       State Region  \
# ...

# %% [markdown]
# ## P2 — Summary
# Use `.info()` and `.describe()`. How many rows have data in every column?

# %%
# your code here
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         180 non-null    int64
#  1   Order ID       180 non-null    str
#  2   Order Date     180 non-null    str
#  3   Ship Date      180 non-null    str
#  4   Ship Mode      180 non-null    str
#  5   Customer ID    180 non-null    str
#  6   Customer Name  180 non-null    str
#  7   Segment        180 non-null    str
#  8   City           180 non-null    str
#  9   State          180 non-null    str
#  10  Region         180 non-null    str
#  11  Product ID     180 non-null    str
#  12  Category       180 non-null    str
#  13  Sub-Category   180 non-null    str
#  14  Product Name   180 non-null    str
#  15  Sales          180 non-null    float64
#  16  Quantity       180 non-null    int64
#  17  Discount       180 non-null    float64
# ...

# %% [markdown]
# ## P3 — One column
# Show just the `Sales` column (first 5 rows).

# %%
# your code here
df["Sales"].head(10)
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# 5     48.8600
# 6      7.2800
# 7    907.1520
# 8     18.5040
# 9    114.9000
# Name: Sales, dtype: float64

# %% [markdown]
# ## P4 — Several columns
# Show `Customer Name`, `Region` and `Sales` (first 5 rows).

# %%
# your code here
df[["Customer Name", "Region", "Sales"]]
# Out:
#         Customer Name   Region     Sales
# 0         Claire Gute    South  261.9600
# 1         Claire Gute    South  731.9400
# 2     Darrin Van Huff     West   14.6200
# 3      Sean O'Donnell    South  957.5775
# 4      Sean O'Donnell    South   22.3680
# ..                ...      ...       ...
# 175  Jennifer Braxton  Central   20.1600
# 176   Shirley Jackson  Central   97.2640
# 177        Joel Eaton     East  396.8020
# 178        Joel Eaton     East   15.8800
# 179          Jim Kriz     East    3.2800
#
# [180 rows x 3 columns]

# %% [markdown]
# ## P5 — The numbers
# Print the total sales, average sale, largest sale and total profit —
# each formatted to 2 decimals.

# %%
# your code here
# round(df["Sales"].sum() , 2)
# df["Sales"].max()
# df["Sales"].mean()
df["Profit"].sum()
# Out:
# np.float64(-598.3015000000003)

# %% [markdown]
# ## P6 — Filter
# Show all rows where Sales are over 1000. How many are there?

# %%
# your code here
# df[df["Sales"] > 1000]
df.loc[df["Sales"] > 1000, ["Sales"]]
# Out:
#         Sales
# 10   1706.184
# 24   1044.630
# 27   3083.430
# 35   1097.544
# 54   1029.950
# 67   1113.024
# 149  1951.840
# 165  8159.952
# 167  1740.060

# %% [markdown]
# ## P7 — Filter on text
# Show all rows from the West region. How many are there?

# %%
# your code here
df[df["Region"] == "West"]
# Out:
#      Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2         3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 5         6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 6         7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 7         8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 8         9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# ..      ...             ...         ...         ...             ...
# 162     163  CA-2016-154508  2016-11-16  2016-11-20  Standard Class
# 163     164  CA-2016-113817  2016-11-07  2016-11-11  Standard Class
# 171     172  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
# 172     173  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
# 173     174  CA-2014-118962  2014-08-05  2014-08-09  Standard Class
#
#     Customer ID    Customer Name    Segment         City       State Region  \
# ...

# %% [markdown]
# ## P8 — Two conditions
# Show rows that are in the West region **and** have Sales over 500.
#
# *Remember: each condition in its own brackets, joined with `&`*

# %%
# your code here
df[(df["Region"] == "West") & (df["Sales"] > 1000)]
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 10      11  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 24      25  CA-2015-106320  2015-09-25  2015-09-30  Standard Class
# 67      68  CA-2014-106376  2014-12-05  2014-12-10  Standard Class
#
#    Customer ID    Customer Name    Segment         City       State Region  \
# 10    BH-11710  Brosina Hoffman   Consumer  Los Angeles  California   West
# 24    EB-13870      Emily Burns   Consumer         Orem        Utah   West
# 67    BS-11590    Brendan Sweed  Corporate      Gilbert     Arizona   West
#
#          Product ID         Category Sub-Category  \
# 10  FUR-TA-10001539        Furniture       Tables
# 24  FUR-TA-10000577        Furniture       Tables
# 67  OFF-AR-10002671  Office Supplies          Art
#
#                                          Product Name     Sales  Quantity  \
# 10           Chromcraft Rectangular Conference Tables  1706.184         9
# ...

# %% [markdown]
# ## P9 — Count values
# How many rows are in each Region? And how many unique Segments are there?

# %%
# your code here

# %% [markdown]
# ## P10 — Group by
# Total sales by Region, biggest first.

# %%
# your code here

# %% [markdown]
# ## CHALLENGE
# 1. Total profit by Category — which category loses money?
# 2. The 5 biggest sales, showing only Product Name and Sales
# 3. Add a new column called `Sales_with_tax` that is Sales x 1.15, then show the first 5 rows

# %%
# your code here
